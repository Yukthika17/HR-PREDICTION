# %% [markdown]
# <a href="https://colab.research.google.com/github/Yukthika17/HR-PREDICTION/blob/main/HR_SALARY_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
data=pd.read_csv('salarydata.csv')

# %%
data.head()
# Out:
#    age         workclass  education  education-num      marital-status  \
# 0   39         State-gov  Bachelors             13       Never-married
# 1   50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2   38           Private    HS-grad              9            Divorced
# 3   53           Private       11th              7  Married-civ-spouse
# 4   28           Private  Bachelors             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country salary
# 0             0              40  United-States  <=50K
# 1             0              13  United-States  <=50K
# 2             0              40  United-States  <=50K
# 3             0              40  United-States  <=50K
# 4             0              40           Cuba  <=50K

# %%
data.tail()
# Out:
#        age     workclass   education  education-num      marital-status  \
# 32556   27       Private  Assoc-acdm             12  Married-civ-spouse
# 32557   40       Private     HS-grad              9  Married-civ-spouse
# 32558   58       Private     HS-grad              9             Widowed
# 32559   22       Private     HS-grad              9       Never-married
# 32560   52  Self-emp-inc     HS-grad              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 32556       Tech-support         Wife  White  Female             0
# 32557  Machine-op-inspct      Husband  White    Male             0
# 32558       Adm-clerical    Unmarried  White  Female             0
# 32559       Adm-clerical    Own-child  White    Male             0
# 32560    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 32556             0              38  United-States  <=50K
# 32557             0              40  United-States   >50K
# 32558             0              40  United-States  <=50K
# 32559             0              20  United-States  <=50K
# 32560             0              40  United-States   >50K

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   education       32561 non-null  object
#  3   education-num   32561 non-null  int64
#  4   marital-status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital-gain    32561 non-null  int64
#  10  capital-loss    32561 non-null  int64
#  11  hours-per-week  32561 non-null  int64
#  12  native-country  32561 non-null  object
#  13  salary          32561 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB

# %%
data.shape
# Out:
# (32561, 14)

# %%
data.isna().sum()
# Out:
# age               0
# workclass         0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
data.drop(['capital-gain','capital-loss','education-num'], axis = 1,inplace = True)
data.head()
# Out:
#    age         workclass  education      marital-status         occupation  \
# 0   39         State-gov  Bachelors       Never-married       Adm-clerical
# 1   50  Self-emp-not-inc  Bachelors  Married-civ-spouse    Exec-managerial
# 2   38           Private    HS-grad            Divorced  Handlers-cleaners
# 3   53           Private       11th  Married-civ-spouse  Handlers-cleaners
# 4   28           Private  Bachelors  Married-civ-spouse     Prof-specialty
#
#     relationship   race     sex  hours-per-week native-country salary
# 0  Not-in-family  White    Male              40  United-States  <=50K
# 1        Husband  White    Male              13  United-States  <=50K
# 2  Not-in-family  White    Male              40  United-States  <=50K
# 3        Husband  Black    Male              40  United-States  <=50K
# 4           Wife  Black  Female              40           Cuba  <=50K

# %%
sns.pairplot(data)

# %%
data.hist(figsize=(20,10))
plt.show()

# %%
#We can check the above using some representations like graphs, barplots, etc

#checking age

plt.hist(data['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(np.arange(20,100,5))
plt.rcParams['figure.figsize'] = (8,8)
plt.title('Age Distribution')
plt.show()

# %%
#checking workclass

data['workclass'].value_counts().plot(kind = 'pie')
plt.rcParams['figure.figsize'] = (10,10)
plt.show()

# %%
#checking education

data['education'].value_counts().plot(kind = 'bar')
plt.xlabel('Education')
plt.ylabel('Count')
plt.rcParams['figure.figsize'] = (10,10)
plt.title('Education level')
plt.show()

# %%
#checking sex

data['sex'].value_counts().plot(kind = 'bar')
plt.rcParams['figure.figsize'] = (10,10)
plt.show()

# %%
#checking occupation

data['occupation'].value_counts().plot(kind = 'bar')
plt.rcParams['figure.figsize'] = (10,10)
plt.show()

# %%
#Checking race

data['race'].value_counts().plot(kind = 'pie')
plt.rcParams['figure.figsize'] = (10,10)
plt.show()

# %%
#checking marital-status

data['marital-status'].value_counts().plot(kind = 'pie')
plt.rcParams['figure.figsize'] = (10,10)
plt.show()

# %%
#checking relationship

data['relationship'].value_counts().plot(kind = 'pie')
plt.rcParams['figure.figsize'] = (10,10)
plt.show()

# %%
#checking native-country

data['native-country'].value_counts().plot(kind = 'bar')
plt.rcParams['figure.figsize'] = (10,10)
plt.yticks(np.arange(5000,33000,3000))
plt.show()

# %%
# Found '?' in columns occupation, workclass, and native-country
data['workclass'].mode()
# Out:
# 0    Private
# Name: workclass, dtype: object

# %%
data['occupation'].mode()
# Out:
# 0    Prof-specialty
# Name: occupation, dtype: object

# %%
data['native-country'].mode()
# Out:
# 0    United-States
# Name: native-country, dtype: object

# %%
dtype: object

# %%
data['workclass'] = data['workclass'].replace('?','Private')
data['occupation']=data['occupation'].replace('?','Prof-speciality')
data['native-country']=data['native-country'].replace('?','United-States')

# %%
data[data['salary']=='?']
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, marital-status, occupation, relationship, race, sex, hours-per-week, native-country, salary]
# Index: []

# %%
#checking whether the records that contains
#the question mark '?' have being removed

#checking occupation

data['occupation'].value_counts().plot(kind = 'bar')
plt.rcParams['figure.figsize'] = (10,10)
plt.show()

# %%
#checking native-country

data['native-country'].value_counts().plot(kind = 'bar')
plt.rcParams['figure.figsize'] = (10,10)
plt.yticks(np.arange(5000,33000,3000))
plt.show()

# %%
#checking workclass

data['workclass'].value_counts().plot(kind = 'pie')
plt.rcParams['figure.figsize'] = (10,10)
plt.show()

# %%
data.plot(kind='box',subplots=True,layout=(2,3),figsize=(14,14));

# %%
plt.boxplot(data['age'])
plt.title('Box plot of age after removal of outlier')
# Out:
# Text(0.5, 1.0, 'Box plot of age after removal of outlier')

# %%
plt.boxplot(data['hours-per-week'])
plt.title('Box plot of hours-per-week after removal of outlier')
# Out:
# Text(0.5, 1.0, 'Box plot of hours-per-week after removal of outlier')

# %%
data.shape
# Out:
# (32561, 11)

# %%
Label Encoding

# %%
from sklearn import preprocessing
label= preprocessing.LabelEncoder()
data['workclass']=label.fit_transform(data['workclass'])
data['education']=label.fit_transform(data['education'])
data['occupation']=label.fit_transform(data['occupation'])
data['sex']=label.fit_transform(data['sex'])
data['salary']=label.fit_transform(data['salary'])
data['race']=label.fit_transform(data['race'])
data['native-country']=label.fit_transform(data['native-country'])
data['marital-status']=label.fit_transform(data['marital-status'])
data['relationship']=label.fit_transform(data['relationship'])

# %%
data
# Out:
#        age  workclass  education  marital-status  occupation  relationship  \
# 0       39          6          9               4           0             1
# 1       50          5          9               2           3             0
# 2       38          3         11               0           5             1
# 3       53          3          1               2           5             0
# 4       28          3          9               2          10             5
# ...    ...        ...        ...             ...         ...           ...
# 32556   27          3          7               2          13             5
# 32557   40          3         11               2           6             0
# 32558   58          3         11               6           0             4
# 32559   22          3         11               4           0             3
# 32560   52          4         11               2           3             5
#
#        race  sex  hours-per-week  native-country  salary
# 0         4    1              40              38       0
# 1         4    1              13              38       0
# 2         4    1              40              38       0
# 3         2    1              40              38       0
# 4         2    0              40               4       0
# ...     ...  ...             ...             ...     ...
# 32556     4    0              38              38       0
# 32557     4    1              40              38       1
# 32558     4    0              40              38       0
# 32559     4    1              20              38       0
# 32560     4    0              40              38       1
#
# [32561 rows x 11 columns]

# %%
x=data.drop(columns=['salary'],axis=1)
y=data['salary']
x.head()
# Out:
#    age  workclass  education  marital-status  occupation  relationship  race  \
# 0   39          6          9               4           0             1     4
# 1   50          5          9               2           3             0     4
# 2   38          3         11               0           5             1     4
# 3   53          3          1               2           5             0     2
# 4   28          3          9               2          10             5     2
#
#    sex  hours-per-week  native-country
# 0    1              40              38
# 1    1              13              38
# 2    1              40              38
# 3    1              40              38
# 4    0              40               4

# %%
#Standard Scaler
from sklearn.model_selection import train_test_split
#train=70
#test=30
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (22792, 10) (9769, 10) (22792,) (9769,)

# %%
from sklearn import preprocessing
scaler=preprocessing.StandardScaler()
x=scaler.fit_transform(x)
x
# Out:
# array([[ 0.03067056,  2.62429763, -0.33543693, ...,  0.70307135,
#         -0.03542945,  0.26136999],
#        [ 0.83710898,  1.72109965, -0.33543693, ...,  0.70307135,
#         -2.22215312,  0.26136999],
#        [-0.04264203, -0.08529633,  0.18133163, ...,  0.70307135,
#         -0.03542945,  0.26136999],
#        ...,
#        [ 1.42360965, -0.08529633,  0.18133163, ..., -1.42233076,
#         -0.03542945,  0.26136999],
#        [-1.21564337, -0.08529633,  0.18133163, ...,  0.70307135,
#         -1.65522476,  0.26136999],
#        [ 0.98373415,  0.81790166,  0.18133163, ..., -1.42233076,
#         -0.03542945,  0.26136999]])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score,precision_score,recall_score,classification_report

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=2000)
lr.fit(x_train,y_train)
pred1=lr.predict(x_test)
con_lr=confusion_matrix(y_test,pred1)
print("The confusion matrix of logistic regression is \n",con_lr)
ac_lr=accuracy_score(y_test,pred1)
print('Accuracy:',ac_lr*100)
# Out:
# The confusion matrix of logistic regression is
#  [[6994  413]
#  [1920  442]]
# Accuracy: 76.11833350394105

# %%
print(classification_report(y_test, pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.86      7407
#            1       0.52      0.19      0.27      2362
#
#     accuracy                           0.76      9769
#    macro avg       0.65      0.57      0.57      9769
# weighted avg       0.72      0.76      0.72      9769

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_values=[]
neighbors=np.arange(70,90)
for k in neighbors:
    knn=KNeighborsClassifier(n_neighbors=k, metric='minkowski')
    knn.fit(x_train, y_train)
    pred2=knn.predict(x_test)
    acc=accuracy_score(y_test,pred2)
    acc_values.append(acc)

# %%
plt.plot(neighbors,acc_values,'o-')
plt.xlabel('k value')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
print(classification_report(y_test, pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      7407
#            1       0.56      0.45      0.50      2362
#
#     accuracy                           0.78      9769
#    macro avg       0.70      0.67      0.68      9769
# weighted avg       0.77      0.78      0.77      9769

# %%
from sklearn.tree import DecisionTreeClassifier
dtr=DecisionTreeClassifier()
dtr.fit(x_train,y_train)
dtr.fit(x_train,y_train)
pred3=dtr.predict(x_test)
con_dtr=confusion_matrix(y_test,pred3)
print("The confusion matrix of decision tree is \n",con_dtr)
ac_dt=accuracy_score(y_test,pred3)
print('Accuracy:',ac_dt*100)
# Out:
# The confusion matrix of decision tree is
#  [[6383 1024]
#  [1130 1232]]
# Accuracy: 77.95066025181697

# %%
print(classification_report(y_test, pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86      7407
#            1       0.55      0.52      0.53      2362
#
#     accuracy                           0.78      9769
#    macro avg       0.70      0.69      0.69      9769
# weighted avg       0.78      0.78      0.78      9769

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
pred4=svc.predict(x_test)
con_svc=confusion_matrix(y_test,pred4)
print("The confusion matrix of decision tree is \n",con_svc)
ac_svc=accuracy_score(y_test,pred4)
print('Accuracy:',ac_svc*100)
# Out:
# The confusion matrix of decision tree is
#  [[7396   11]
#  [2355    7]]
# Accuracy: 75.78053024874603

# %%
print(classification_report(y_test, pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86      7407
#            1       0.39      0.00      0.01      2362
#
#     accuracy                           0.76      9769
#    macro avg       0.57      0.50      0.43      9769
# weighted avg       0.67      0.76      0.66      9769

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
pred5=rf.predict(x_test)
con_rf=confusion_matrix(y_test,pred5)
print("The confusion matrix of random forest is \n",con_rf)
ac_rf=accuracy_score(y_test,pred5)
print('Accuracy:',ac_rf*100)
# Out:
# The confusion matrix of random forest is
#  [[6709  698]
#  [1068 1294]]
# Accuracy: 81.92240761592794

# %%
print(classification_report(y_test, pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      7407
#            1       0.65      0.55      0.59      2362
#
#     accuracy                           0.82      9769
#    macro avg       0.76      0.73      0.74      9769
# weighted avg       0.81      0.82      0.81      9769

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_values=[]
neighbors=np.arange(70,90)
for k in neighbors:
    knn=KNeighborsClassifier(n_neighbors=k, metric='minkowski')
    knn.fit(x_train, y_train)
    pred2=knn.predict(x_test)
    acc=accuracy_score(y_test,pred2)
    acc_values.append(acc)
ac_knn = max(acc_values) # Assign the maximum accuracy to ac_knn

print("The accuracy of Logistic Regression is:",ac_lr*100)
print("The accuracy of KNN is:",ac_knn*100)
print("The accuracy of Decision tree is:",ac_dt*100)
print("The accuracy of SVM is:",ac_svc*100)
print("The accuracy of Random forest  is:",ac_rf*100)
# Out:
# The accuracy of Logistic Regression is: 76.11833350394105
# The accuracy of KNN is: 78.43177397891289
# The accuracy of Decision tree is: 77.95066025181697
# The accuracy of SVM is: 75.78053024874603
# The accuracy of Random forest  is: 81.92240761592794

# %%
from tabulate import tabulate

# %%
table = [['Model', 'Accuracy'], ['Logistic Regression',ac_lr], ['KNN',ac_knn],['Decision tree',ac_dt],["SVM",ac_svc],['Random Forest',ac_rf]]
print(tabulate(table,headers='firstrow',tablefmt='fancy_grid'))
# Out:
# ╒═════════════════════╤════════════╕
# │ Model               │   Accuracy │
# ╞═════════════════════╪════════════╡
# │ Logistic Regression │   0.761183 │
# ├─────────────────────┼────────────┤
# │ KNN                 │   0.784318 │
# ├─────────────────────┼────────────┤
# │ Decision tree       │   0.779507 │
# ├─────────────────────┼────────────┤
# │ SVM                 │   0.757805 │
# ├─────────────────────┼────────────┤
# │ Random Forest       │   0.819224 │
# ╘═════════════════════╧════════════╛

# %%
rf=RandomForestClassifier(criterion='gini',max_depth=10,n_estimators=600)
rf.fit(x_train,y_train)
y_pr=rf.predict(x_test)
acc_sc=accuracy_score(y_test,y_pr)*100
acc_sc
# Out:
# 83.32480294810114
